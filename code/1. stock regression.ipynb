# %% [markdown]
# # What's SP500 next day stock price forecast?

# %% [markdown]
# ## 1. data preparation

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from aiconf import fit_scaler, scale, prepare_regression_samples, plots

WINDOW = 7
TEST_SIZE = 0.2
RANDOM_SEED = 42 #it makes results reproducible: only for test!!!
#RANDOM_SEED = None #uncomment me for real training!!!
print "- SP500 historical OHCLV sample:"
df = pd.read_csv('/data/historical-SP500.csv', index_col='Date', parse_dates=True).sort_index()
df = df[df.index.values > np.datetime64('2000-01-01')]
close = df['Close'][0:(1250+WINDOW+1)]

fit_scaler(close, TEST_SIZE)
sclose = scale(close)

X,y = prepare_regression_samples(sclose, WINDOW)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_SEED, shuffle=True)
print df[["Open", "High", "Low", "Close", "Volume"]].head()
print ""
print "- close values plot versus normalized (between 0 and 1) close values plot:"
plots(close, sclose)
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# - SP500 historical OHCLV sample:
#                    Open         High          Low        Close      Volume
# Date
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971   931800000
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1009000000
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1085500000
# 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1092300000
# 2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971  1225200000
#
# - close values plot versus normalized (between 0 and 1) close values plot:

# %%
print "-INPUT sample is an array of the last week prices of the given price, OUTPUT is the next day price of the given price:"
print "X:", X[0:2],"\ny:",y[0:2]
print ""
print "- split X, y into test and validation sets (0.20%):"
print "the size of train set (X_train, Y_train) is ", X_train.shape[0], " and the size of validation/test set (X_test, y_test) is", X_test.shape[0]
# Out:
# -INPUT sample is an array of the last week prices of the given price, OUTPUT is the next day price of the given price:
# X: [[0.90376982 0.82943929 0.83302253 0.83480749 0.88545358 0.9069402
#   0.88157732]
#  [0.82943929 0.83302253 0.83480749 0.88545358 0.9069402  0.88157732
#   0.87317175]]
# y: [0.87317175 0.89639015]
#
# - split X, y into test and validation sets (0.20%):
# the size of train set (X_train, Y_train) is  1000  and the size of validation/test set (X_test, y_test) is 250

# %% [markdown]
# ## 2. choose, build and compile the model
# - which model should you choose?
# - How to choose the number of hidden layers and nodes?
# - How should I choose a proper activation function for the neural network?
# - Which optimizer and error function should I use?
# - Which learning rate and error function should I use?

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU

#Y = fa(W*X + b)

model = Sequential()
model.add(Dense(64, input_shape = (WINDOW, ), activation="relu", kernel_initializer='normal'))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mse', metrics=[])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                512
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 577
# Trainable params: 577
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. train the model

# %%
history = model.fit(
        X_train, y_train, epochs=30, batch_size=32, 
        validation_data=(X_test, y_test), verbose=1)

score = model.evaluate(X_test, y_test, batch_size=32)
print "loss:", score
# Out:
# Train on 1000 samples, validate on 250 samples
# Epoch 1/30
# 1000/1000 [==============================] - 0s 354us/step - loss: 0.0993 - val_loss: 0.0050
# Epoch 2/30
# 1000/1000 [==============================] - 0s 188us/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 3/30
# 1000/1000 [==============================] - 0s 202us/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 4/30
# 1000/1000 [==============================] - 0s 157us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 5/30
# 1000/1000 [==============================] - 0s 80us/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 6/30
# 1000/1000 [==============================] - 0s 81us/step - loss: 8.4301e-04 - val_loss: 9.8980e-04
# Epoch 7/30
# 1000/1000 [==============================] - 0s 81us/step - loss: 7.8492e-04 - val_loss: 9.3873e-04
# Epoch 8/30
# 1000/1000 [==============================] - 0s 64us/step - loss: 7.6620e-04 - val_loss: 9.1359e-04
# Epoch 9/30
# 1000/1000 [==============================] - 0s 96us/step - loss: 7.4204e-04 - val_loss: 9.4328e-04
# Epoch 10/30
# 1000/1000 [==============================] - 0s 74us/step - loss: 7.4697e-04 - val_loss: 8.3862e-04
# Epoch 11/30
# 1000/1000 [==============================] - 0s 88us/step - loss: 6.8349e-04 - val_loss: 7.8334e-04
# Epoch 12/30
# 1000/1000 [==============================] - 0s 102us/step - loss: 6.5297e-04 - val_loss: 7.4434e-04
# Epoch 13/30
# 1000/1000 [==============================] - 0s 58us/step - loss: 6.5206e-04 - val_loss: 7.5811e-04
# Epoch 14/30
# 1000/1000 [==============================] - 0s 87us/step - loss: 6.2344e-04 - val_loss: 7.0792e-04
# Epoch 15/30
# 1000/1000 [==============================] - 0s 78us/step - loss: 5.9391e-04 - val_loss: 6.8736e-04
# Epoch 16/30
# 1000/1000 [==============================] - 0s 72us/step - loss: 5.9703e-04 - val_loss: 6.8188e-04
# Epoch 17/30
# 1000/1000 [==============================] - 0s 77us/step - loss: 5.8839e-04 - val_loss: 6.6270e-04
# Epoch 18/30
# 1000/1000 [==============================] - 0s 98us/step - loss: 5.9647e-04 - val_loss: 6.7166e-04
# Epoch 19/30
# 1000/1000 [==============================] - 0s 90us/step - loss: 5.5768e-04 - val_loss: 6.3354e-04
# Epoch 20/30
# 1000/1000 [==============================] - 0s 112us/step - loss: 5.4581e-04 - val_loss: 6.2160e-04
# Epoch 21/30
# 1000/1000 [==============================] - 0s 77us/step - loss: 5.2867e-04 - val_loss: 6.1604e-04
# Epoch 22/30
# 1000/1000 [==============================] - 0s 80us/step - loss: 5.2497e-04 - val_loss: 6.2353e-04
# Epoch 23/30
# 1000/1000 [==============================] - 0s 79us/step - loss: 5.2681e-04 - val_loss: 6.7644e-04
# Epoch 24/30
# 1000/1000 [==============================] - 0s 77us/step - loss: 5.4962e-04 - val_loss: 6.2000e-04
# Epoch 25/30
# 1000/1000 [==============================] - 0s 82us/step - loss: 5.1914e-04 - val_loss: 5.8488e-04
# Epoch 26/30
# 1000/1000 [==============================] - 0s 80us/step - loss: 5.0587e-04 - val_loss: 6.2760e-04
# Epoch 27/30
# 1000/1000 [==============================] - 0s 81us/step - loss: 5.1394e-04 - val_loss: 5.9794e-04
# Epoch 28/30
# 1000/1000 [==============================] - 0s 129us/step - loss: 4.9182e-04 - val_loss: 5.5010e-04
# Epoch 29/30
# 1000/1000 [==============================] - 0s 194us/step - loss: 4.7821e-04 - val_loss: 5.5344e-04
# Epoch 30/30
# 1000/1000 [==============================] - 0s 104us/step - loss: 4.9858e-04 - val_loss: 5.4554e-04
# 250/250 [==============================] - 0s 90us/step
# loss: 0.0005455389888957143

# %%
from aiconf import plot_model_performance
#0.0006843569851480425
plot_model_performance(history, model, close, X, y, TEST_SIZE)
# Out:
# SCORE model 0.00015210342244245111

# %% [markdown]
# ## 4. Tuning hyperparameters / hyperparameters optimization
# - how I can optimize the performance of the model?
# - how I can choose the best values of the model parameters?

# %%
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

def create_model(nodes, optimizer, dropout, init):
    model = Sequential()
    model.add(Dense(nodes, kernel_initializer=init, input_shape = (WINDOW, ), activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(1, kernel_initializer=init, activation='linear'))
    model.compile(optimizer=optimizer, loss='mse')
    return model

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

epochs = [30, 50, 100, 150]
batches = [32, 64, 128, 256, 512]
optimizers = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
nodes = [32, 64, 256, 512]
dropouts = [0.1, 0.2, 0.25, 3]
init_modes = ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']

modelf = KerasRegressor(build_fn=create_model, batch_size = 64, nb_epoch = 30, nodes = 512, optimizer='adam', dropout=0.1, init='he_uniform', verbose = 1)

param_grid = {
    #'nb_epoch': epochs,
    'nodes': nodes,
    #'batch_size':batches,
    'optimizer':optimizers,
    #'dropout':dropouts,
    #'init':init_modes,
}

validator = GridSearchCV(estimator=modelf, param_grid=param_grid, n_jobs=1, verbose=2)
grid_result = validator.fit(X, y)
print('The parameters of the best model are: ')
print(validator.best_params_)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
for params, mean_score, scores in grid_result.grid_scores_:
    print("%f (%f) with: %r" % (scores.mean(), scores.std(), params))
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [CV] nodes=32, optimizer=SGD .........................................
# Epoch 1/1
# 833/833 [==============================] - 0s 219us/step - loss: 0.1093
# 417/417 [==============================] - 0s 152us/step
# 833/833 [==============================] - 0s 60us/step
# [CV] .......................... nodes=32, optimizer=SGD, total=   0.7s
# [CV] nodes=32, optimizer=SGD .........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# Epoch 1/1
# 833/833 [==============================] - 0s 132us/step - loss: 0.2783
# 417/417 [==============================] - 0s 93us/step
# 833/833 [==============================] - 0s 29us/step
# [CV] .......................... nodes=32, optimizer=SGD, total=   0.4s
# [CV] nodes=32, optimizer=SGD .........................................
# Epoch 1/1
# 834/834 [==============================] - 0s 255us/step - loss: 0.0663
# 416/416 [==============================] - 0s 195us/step
# 834/834 [==============================] - 0s 41us/step
# [CV] .......................... nodes=32, optimizer=SGD, total=   0.5s
# [CV] nodes=32, optimizer=RMSprop .....................................
# Epoch 1/1
# 833/833 [==============================] - 0s 253us/step - loss: 0.7056
# 417/417 [==============================] - 0s 145us/step
# 833/833 [==============================] - 0s 46us/step
# [CV] ...................... nodes=32, optimizer=RMSprop, total=   0.6s
# [CV] nodes=32, optimizer=RMSprop .....................................
# Epoch 1/1
# 833/833 [==============================] - 0s 212us/step - loss: 0.1057
# 417/417 [==============================] - 0s 152us/step
# 833/833 [==============================] - 0s 50us/step
# [CV] ...................... nodes=32, optimizer=RMSprop, total=   0.6s
# [CV] nodes=32, optimizer=RMSprop .....................................
# Epoch 1/1
# 834/834 [==============================] - 0s 214us/step - loss: 2.7223
# 416/416 [==============================] - 0s 145us/step
# 834/834 [==============================] - 0s 41us/step
# [CV] ...................... nodes=32, optimizer=RMSprop, total=   0.5s
# [CV] nodes=32, optimizer=Adagrad .....................................
# Epoch 1/1
# 833/833 [==============================] - 0s 223us/step - loss: 0.6297
# 417/417 [==============================] - 0s 173us/step
# 833/833 [==============================] - 0s 32us/step
# [CV] ...................... nodes=32, optimizer=Adagrad, total=   0.5s
# [CV] nodes=32, optimizer=Adagrad .....................................
# Epoch 1/1
# 833/833 [==============================] - 0s 480us/step - loss: 0.1356
# 417/417 [==============================] - 0s 338us/step
# 833/833 [==============================] - 0s 58us/step
# [CV] ...................... nodes=32, optimizer=Adagrad, total=   0.9s
# [CV] nodes=32, optimizer=Adagrad .....................................
# Epoch 1/1
# 834/834 [==============================] - 0s 250us/step - loss: 0.1958
# 416/416 [==============================] - 0s 316us/step
# 834/834 [==============================] - 0s 58us/step
# [CV] ...................... nodes=32, optimizer=Adagrad, total=   0.8s
# [CV] nodes=32, optimizer=Adadelta ....................................
# Epoch 1/1
# 833/833 [==============================] - 0s 404us/step - loss: 1.1839
# 417/417 [==============================] - 0s 408us/step
# 833/833 [==============================] - 0s 66us/step
# [CV] ..................... nodes=32, optimizer=Adadelta, total=   0.8s
# [CV] nodes=32, optimizer=Adadelta ....................................
# Epoch 1/1
# 833/833 [==============================] - 0s 468us/step - loss: 4.2163
# 417/417 [==============================] - 0s 227us/step
# 833/833 [==============================] - 0s 69us/step
# [CV] ..................... nodes=32, optimizer=Adadelta, total=   1.0s
# [CV] nodes=32, optimizer=Adadelta ....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 616us/step - loss: 0.3548
# 416/416 [==============================] - 0s 317us/step
# 834/834 [==============================] - 0s 38us/step
# [CV] ..................... nodes=32, optimizer=Adadelta, total=   1.2s
# [CV] nodes=32, optimizer=Adam ........................................
# Epoch 1/1
# 833/833 [==============================] - 0s 397us/step - loss: 0.2574
# 417/417 [==============================] - 0s 296us/step
# 833/833 [==============================] - 0s 34us/step
# [CV] ......................... nodes=32, optimizer=Adam, total=   0.9s
# [CV] nodes=32, optimizer=Adam ........................................
# Epoch 1/1
# 833/833 [==============================] - 0s 543us/step - loss: 0.2781
# 417/417 [==============================] - 0s 334us/step
# 833/833 [==============================] - 0s 33us/step
# [CV] ......................... nodes=32, optimizer=Adam, total=   1.0s
# [CV] nodes=32, optimizer=Adam ........................................
# Epoch 1/1
# 834/834 [==============================] - 0s 426us/step - loss: 0.0709
# 416/416 [==============================] - 0s 410us/step
# 834/834 [==============================] - 0s 64us/step
# [CV] ......................... nodes=32, optimizer=Adam, total=   0.9s
# [CV] nodes=32, optimizer=Adamax ......................................
# Epoch 1/1
# 833/833 [==============================] - 0s 486us/step - loss: 0.0606
# 417/417 [==============================] - 0s 417us/step
# 833/833 [==============================] - 0s 51us/step
# [CV] ....................... nodes=32, optimizer=Adamax, total=   1.0s
# [CV] nodes=32, optimizer=Adamax ......................................
# Epoch 1/1
# 833/833 [==============================] - 0s 579us/step - loss: 0.3632
# 417/417 [==============================] - 0s 376us/step
# 833/833 [==============================] - 0s 47us/step
# [CV] ....................... nodes=32, optimizer=Adamax, total=   1.0s
# [CV] nodes=32, optimizer=Adamax ......................................
# Epoch 1/1
# 834/834 [==============================] - 0s 473us/step - loss: 2.0956
# 416/416 [==============================] - 0s 389us/step
# 834/834 [==============================] - 0s 41us/step
# [CV] ....................... nodes=32, optimizer=Adamax, total=   0.9s
# [CV] nodes=32, optimizer=Nadam .......................................
# Epoch 1/1
# 833/833 [==============================] - 0s 529us/step - loss: 0.0231
# 417/417 [==============================] - 0s 386us/step
# 833/833 [==============================] - 0s 33us/step
# [CV] ........................ nodes=32, optimizer=Nadam, total=   0.9s
# [CV] nodes=32, optimizer=Nadam .......................................
# Epoch 1/1
# 833/833 [==============================] - 0s 535us/step - loss: 0.0933
# 417/417 [==============================] - 0s 401us/step
# 833/833 [==============================] - 0s 44us/step
# [CV] ........................ nodes=32, optimizer=Nadam, total=   0.9s
# [CV] nodes=32, optimizer=Nadam .......................................
# Epoch 1/1
# 834/834 [==============================] - 0s 554us/step - loss: 0.6936
# 416/416 [==============================] - 0s 479us/step
# 834/834 [==============================] - 0s 52us/step
# [CV] ........................ nodes=32, optimizer=Nadam, total=   1.2s
# [CV] nodes=64, optimizer=SGD .........................................
# Epoch 1/1
# 833/833 [==============================] - 0s 531us/step - loss: 0.2592
# 417/417 [==============================] - 0s 423us/step
# 833/833 [==============================] - 0s 36us/step
# [CV] .......................... nodes=64, optimizer=SGD, total=   0.9s
# [CV] nodes=64, optimizer=SGD .........................................
# Epoch 1/1
# 833/833 [==============================] - 1s 633us/step - loss: 0.1979
# 417/417 [==============================] - 0s 529us/step
# 833/833 [==============================] - 0s 42us/step
# [CV] .......................... nodes=64, optimizer=SGD, total=   1.0s
# [CV] nodes=64, optimizer=SGD .........................................
# Epoch 1/1
# 834/834 [==============================] - 1s 661us/step - loss: 0.0466
# 416/416 [==============================] - 0s 567us/step
# 834/834 [==============================] - 0s 65us/step
# [CV] .......................... nodes=64, optimizer=SGD, total=   1.1s
# [CV] nodes=64, optimizer=RMSprop .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 688us/step - loss: 0.0999
# 417/417 [==============================] - 0s 569us/step
# 833/833 [==============================] - 0s 41us/step
# [CV] ...................... nodes=64, optimizer=RMSprop, total=   1.1s
# [CV] nodes=64, optimizer=RMSprop .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 688us/step - loss: 0.0907
# 417/417 [==============================] - 0s 607us/step
# 833/833 [==============================] - 0s 51us/step
# [CV] ...................... nodes=64, optimizer=RMSprop, total=   1.2s
# [CV] nodes=64, optimizer=RMSprop .....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 710us/step - loss: 2.3490
# 416/416 [==============================] - 0s 611us/step
# 834/834 [==============================] - 0s 49us/step
# [CV] ...................... nodes=64, optimizer=RMSprop, total=   1.2s
# [CV] nodes=64, optimizer=Adagrad .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 733us/step - loss: 0.2742
# 417/417 [==============================] - 0s 615us/step
# 833/833 [==============================] - 0s 45us/step
# [CV] ...................... nodes=64, optimizer=Adagrad, total=   1.1s
# [CV] nodes=64, optimizer=Adagrad .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 706us/step - loss: 0.0698
# 417/417 [==============================] - 0s 529us/step
# 833/833 [==============================] - 0s 28us/step
# [CV] ...................... nodes=64, optimizer=Adagrad, total=   1.4s
# [CV] nodes=64, optimizer=Adagrad .....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 646us/step - loss: 0.0850
# 416/416 [==============================] - 0s 537us/step
# 834/834 [==============================] - 0s 33us/step
# [CV] ...................... nodes=64, optimizer=Adagrad, total=   1.0s
# [CV] nodes=64, optimizer=Adadelta ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 704us/step - loss: 1.4357
# 417/417 [==============================] - 0s 581us/step
# 833/833 [==============================] - 0s 34us/step
# [CV] ..................... nodes=64, optimizer=Adadelta, total=   1.1s
# [CV] nodes=64, optimizer=Adadelta ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 699us/step - loss: 0.3424
# 417/417 [==============================] - 0s 591us/step
# 833/833 [==============================] - 0s 39us/step
# [CV] ..................... nodes=64, optimizer=Adadelta, total=   1.1s
# [CV] nodes=64, optimizer=Adadelta ....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 719us/step - loss: 0.1372
# 416/416 [==============================] - 0s 599us/step
# 834/834 [==============================] - 0s 44us/step
# [CV] ..................... nodes=64, optimizer=Adadelta, total=   1.1s
# [CV] nodes=64, optimizer=Adam ........................................
# Epoch 1/1
# 833/833 [==============================] - 1s 752us/step - loss: 0.2714
# 417/417 [==============================] - 0s 630us/step
# 833/833 [==============================] - 0s 64us/step
# [CV] ......................... nodes=64, optimizer=Adam, total=   1.2s
# [CV] nodes=64, optimizer=Adam ........................................
# Epoch 1/1
# 833/833 [==============================] - 1s 776us/step - loss: 2.0187
# 417/417 [==============================] - 0s 647us/step
# 833/833 [==============================] - 0s 40us/step
# [CV] ......................... nodes=64, optimizer=Adam, total=   1.2s
# [CV] nodes=64, optimizer=Adam ........................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.8062
# 416/416 [==============================] - 0s 657us/step
# 834/834 [==============================] - 0s 45us/step
# [CV] ......................... nodes=64, optimizer=Adam, total=   1.5s
# [CV] nodes=64, optimizer=Adamax ......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 945us/step - loss: 0.2428
# 417/417 [==============================] - 0s 793us/step
# 833/833 [==============================] - 0s 40us/step
# [CV] ....................... nodes=64, optimizer=Adamax, total=   1.4s
# [CV] nodes=64, optimizer=Adamax ......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 838us/step - loss: 0.2599
# 417/417 [==============================] - 0s 688us/step
# 833/833 [==============================] - 0s 38us/step
# [CV] ....................... nodes=64, optimizer=Adamax, total=   1.3s
# [CV] nodes=64, optimizer=Adamax ......................................
# Epoch 1/1
# 834/834 [==============================] - 1s 879us/step - loss: 0.3361
# 416/416 [==============================] - 0s 713us/step
# 834/834 [==============================] - 0s 40us/step
# [CV] ....................... nodes=64, optimizer=Adamax, total=   1.3s
# [CV] nodes=64, optimizer=Nadam .......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 891us/step - loss: 0.8788
# 417/417 [==============================] - 0s 742us/step
# 833/833 [==============================] - 0s 37us/step
# [CV] ........................ nodes=64, optimizer=Nadam, total=   1.4s
# [CV] nodes=64, optimizer=Nadam .......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 917us/step - loss: 0.9159
# 417/417 [==============================] - 0s 763us/step
# 833/833 [==============================] - 0s 41us/step
# [CV] ........................ nodes=64, optimizer=Nadam, total=   1.4s
# [CV] nodes=64, optimizer=Nadam .......................................
# Epoch 1/1
# 834/834 [==============================] - 1s 939us/step - loss: 0.1075
# 416/416 [==============================] - 0s 767us/step
# 834/834 [==============================] - 0s 36us/step
# [CV] ........................ nodes=64, optimizer=Nadam, total=   1.4s
# [CV] nodes=256, optimizer=SGD ........................................
# Epoch 1/1
# 833/833 [==============================] - 1s 970us/step - loss: 0.0451
# 417/417 [==============================] - 0s 819us/step
# 833/833 [==============================] - 0s 38us/step
# [CV] ......................... nodes=256, optimizer=SGD, total=   1.4s
# [CV] nodes=256, optimizer=SGD ........................................
# Epoch 1/1
# 833/833 [==============================] - 1s 953us/step - loss: 0.4417
# 417/417 [==============================] - 0s 810us/step
# 833/833 [==============================] - 0s 41us/step
# [CV] ......................... nodes=256, optimizer=SGD, total=   1.4s
# [CV] nodes=256, optimizer=SGD ........................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.5709
# 416/416 [==============================] - 0s 905us/step
# 834/834 [==============================] - 0s 47us/step
# [CV] ......................... nodes=256, optimizer=SGD, total=   1.5s
# [CV] nodes=256, optimizer=RMSprop ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0438
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 51us/step
# [CV] ..................... nodes=256, optimizer=RMSprop, total=   1.7s
# [CV] nodes=256, optimizer=RMSprop ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0960
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 51us/step
# [CV] ..................... nodes=256, optimizer=RMSprop, total=   2.1s
# [CV] nodes=256, optimizer=RMSprop ....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.4945
# 416/416 [==============================] - 0s 1ms/step
# 834/834 [==============================] - 0s 53us/step
# [CV] ..................... nodes=256, optimizer=RMSprop, total=   1.8s
# [CV] nodes=256, optimizer=Adagrad ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0782
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 50us/step
# [CV] ..................... nodes=256, optimizer=Adagrad, total=   1.8s
# [CV] nodes=256, optimizer=Adagrad ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.2097
# 417/417 [==============================] - 0s 919us/step
# 833/833 [==============================] - 0s 41us/step
# [CV] ..................... nodes=256, optimizer=Adagrad, total=   1.5s
# [CV] nodes=256, optimizer=Adagrad ....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.1569
# 416/416 [==============================] - 0s 916us/step
# 834/834 [==============================] - 0s 41us/step
# [CV] ..................... nodes=256, optimizer=Adagrad, total=   1.5s
# [CV] nodes=256, optimizer=Adadelta ...................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0731
# 417/417 [==============================] - 0s 965us/step
# 833/833 [==============================] - 0s 38us/step
# [CV] .................... nodes=256, optimizer=Adadelta, total=   1.6s
# [CV] nodes=256, optimizer=Adadelta ...................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0838
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 42us/step
# [CV] .................... nodes=256, optimizer=Adadelta, total=   1.7s
# [CV] nodes=256, optimizer=Adadelta ...................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.1103
# 416/416 [==============================] - 0s 1ms/step
# 834/834 [==============================] - 0s 41us/step
# [CV] .................... nodes=256, optimizer=Adadelta, total=   1.7s
# [CV] nodes=256, optimizer=Adam .......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.1269
# 417/417 [==============================] - 0s 996us/step
# 833/833 [==============================] - 0s 49us/step
# [CV] ........................ nodes=256, optimizer=Adam, total=   1.7s
# [CV] nodes=256, optimizer=Adam .......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.1356
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 42us/step
# [CV] ........................ nodes=256, optimizer=Adam, total=   1.7s
# [CV] nodes=256, optimizer=Adam .......................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.1631
# 416/416 [==============================] - 0s 1ms/step
# 834/834 [==============================] - 0s 29us/step
# [CV] ........................ nodes=256, optimizer=Adam, total=   1.7s
# [CV] nodes=256, optimizer=Adamax .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0489
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 56us/step
# [CV] ...................... nodes=256, optimizer=Adamax, total=   1.8s
# [CV] nodes=256, optimizer=Adamax .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.2151
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 40us/step
# [CV] ...................... nodes=256, optimizer=Adamax, total=   1.8s
# [CV] nodes=256, optimizer=Adamax .....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.4426
# 416/416 [==============================] - 0s 1ms/step
# 834/834 [==============================] - 0s 37us/step
# [CV] ...................... nodes=256, optimizer=Adamax, total=   2.1s
# [CV] nodes=256, optimizer=Nadam ......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.1443
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 36us/step
# [CV] ....................... nodes=256, optimizer=Nadam, total=   1.9s
# [CV] nodes=256, optimizer=Nadam ......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.1085
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 43us/step
# [CV] ....................... nodes=256, optimizer=Nadam, total=   1.9s
# [CV] nodes=256, optimizer=Nadam ......................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.4216
# 416/416 [==============================] - 0s 1ms/step
# 834/834 [==============================] - 0s 43us/step
# [CV] ....................... nodes=256, optimizer=Nadam, total=   1.9s
# [CV] nodes=512, optimizer=SGD ........................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0411
# 417/417 [==============================] - 0s 1ms/step
# 833/833 [==============================] - 0s 33us/step
# [CV] ......................... nodes=512, optimizer=SGD, total=   1.9s
# [CV] nodes=512, optimizer=SGD ........................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 279.5858
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 40us/step
# [CV] ......................... nodes=512, optimizer=SGD, total=   1.9s
# [CV] nodes=512, optimizer=SGD ........................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 212.6513
# 416/416 [==============================] - 1s 1ms/step
# 834/834 [==============================] - 0s 45us/step
# [CV] ......................... nodes=512, optimizer=SGD, total=   1.9s
# [CV] nodes=512, optimizer=RMSprop ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.0433
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 58us/step
# [CV] ..................... nodes=512, optimizer=RMSprop, total=   2.1s
# [CV] nodes=512, optimizer=RMSprop ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.2700
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 56us/step
# [CV] ..................... nodes=512, optimizer=RMSprop, total=   2.0s
# [CV] nodes=512, optimizer=RMSprop ....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 1ms/step - loss: 0.6659
# 416/416 [==============================] - 1s 1ms/step
# 834/834 [==============================] - 0s 50us/step
# [CV] ..................... nodes=512, optimizer=RMSprop, total=   2.0s
# [CV] nodes=512, optimizer=Adagrad ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 1ms/step - loss: 0.1428
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 51us/step
# [CV] ..................... nodes=512, optimizer=Adagrad, total=   2.0s
# [CV] nodes=512, optimizer=Adagrad ....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 2ms/step - loss: 0.3463
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 47us/step
# [CV] ..................... nodes=512, optimizer=Adagrad, total=   2.1s
# [CV] nodes=512, optimizer=Adagrad ....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 2ms/step - loss: 0.3228
# 416/416 [==============================] - 1s 2ms/step
# 834/834 [==============================] - 0s 56us/step
# [CV] ..................... nodes=512, optimizer=Adagrad, total=   2.2s
# [CV] nodes=512, optimizer=Adadelta ...................................
# Epoch 1/1
# 833/833 [==============================] - 1s 2ms/step - loss: 0.0682
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 50us/step
# [CV] .................... nodes=512, optimizer=Adadelta, total=   2.2s
# [CV] nodes=512, optimizer=Adadelta ...................................
# Epoch 1/1
# 833/833 [==============================] - 1s 2ms/step - loss: 0.1533
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 53us/step
# [CV] .................... nodes=512, optimizer=Adadelta, total=   2.2s
# [CV] nodes=512, optimizer=Adadelta ...................................
# Epoch 1/1
# 834/834 [==============================] - 1s 2ms/step - loss: 0.4054
# 416/416 [==============================] - 1s 1ms/step
# 834/834 [==============================] - 0s 47us/step
# [CV] .................... nodes=512, optimizer=Adadelta, total=   2.2s
# [CV] nodes=512, optimizer=Adam .......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 2ms/step - loss: 0.1080
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 55us/step
# [CV] ........................ nodes=512, optimizer=Adam, total=   2.7s
# [CV] nodes=512, optimizer=Adam .......................................
# Epoch 1/1
# 833/833 [==============================] - 1s 2ms/step - loss: 1.4216
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 48us/step
# [CV] ........................ nodes=512, optimizer=Adam, total=   2.3s
# [CV] nodes=512, optimizer=Adam .......................................
# Epoch 1/1
# 834/834 [==============================] - 1s 2ms/step - loss: 0.2604
# 416/416 [==============================] - 1s 1ms/step
# 834/834 [==============================] - 0s 48us/step
# [CV] ........................ nodes=512, optimizer=Adam, total=   2.3s
# [CV] nodes=512, optimizer=Adamax .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 2ms/step - loss: 0.0522
# 417/417 [==============================] - 1s 1ms/step
# 833/833 [==============================] - 0s 51us/step
# [CV] ...................... nodes=512, optimizer=Adamax, total=   2.3s
# [CV] nodes=512, optimizer=Adamax .....................................
# Epoch 1/1
# 833/833 [==============================] - 1s 2ms/step - loss: 0.3084
# 417/417 [==============================] - 1s 2ms/step
# 833/833 [==============================] - 0s 44us/step
# [CV] ...................... nodes=512, optimizer=Adamax, total=   2.3s
# [CV] nodes=512, optimizer=Adamax .....................................
# Epoch 1/1
# 834/834 [==============================] - 1s 2ms/step - loss: 0.1560
# 416/416 [==============================] - 1s 2ms/step
# 834/834 [==============================] - 0s 47us/step
# [CV] ...................... nodes=512, optimizer=Adamax, total=   2.4s
# [CV] nodes=512, optimizer=Nadam ......................................
# Epoch 1/1
# 833/833 [==============================] - 2s 2ms/step - loss: 0.0381
# 417/417 [==============================] - 1s 2ms/step
# 833/833 [==============================] - 0s 47us/step
# [CV] ....................... nodes=512, optimizer=Nadam, total=   2.8s
# [CV] nodes=512, optimizer=Nadam ......................................
# Epoch 1/1
# 833/833 [==============================] - 2s 2ms/step - loss: 0.1087
# 417/417 [==============================] - 1s 2ms/step
# 833/833 [==============================] - 0s 51us/step
# [CV] ....................... nodes=512, optimizer=Nadam, total=   2.7s
# [CV] nodes=512, optimizer=Nadam ......................................
# Epoch 1/1
# 834/834 [==============================] - 2s 2ms/step - loss: 0.0817
# 416/416 [==============================] - 1s 2ms/step
# 834/834 [==============================] - 0s 129us/step
# [CV] ....................... nodes=512, optimizer=Nadam, total=   2.9s
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:  2.2min finished
# Epoch 1/1
# 1250/1250 [==============================] - 2s 1ms/step - loss: 0.5388
# The parameters of the best model are:
# {'nodes': 256, 'optimizer': 'RMSprop'}
# Best: -0.005926 using {'nodes': 256, 'optimizer': 'RMSprop'}
# -0.071576 (0.093799) with: {'nodes': 32, 'optimizer': 'SGD'}
# -0.899578 (0.762023) with: {'nodes': 32, 'optimizer': 'RMSprop'}
# -0.238992 (0.325009) with: {'nodes': 32, 'optimizer': 'Adagrad'}
# -1.413257 (1.476112) with: {'nodes': 32, 'optimizer': 'Adadelta'}
# -0.184173 (0.248502) with: {'nodes': 32, 'optimizer': 'Adam'}
# -0.189201 (0.255351) with: {'nodes': 32, 'optimizer': 'Adamax'}
# -0.027086 (0.035642) with: {'nodes': 32, 'optimizer': 'Nadam'}
# -0.028003 (0.033871) with: {'nodes': 64, 'optimizer': 'SGD'}
# -0.161262 (0.208910) with: {'nodes': 64, 'optimizer': 'RMSprop'}
# -0.012972 (0.005726) with: {'nodes': 64, 'optimizer': 'Adagrad'}
# -0.942752 (1.327960) with: {'nodes': 64, 'optimizer': 'Adadelta'}
# -0.176073 (0.071118) with: {'nodes': 64, 'optimizer': 'Adam'}
# -0.036767 (0.048151) with: {'nodes': 64, 'optimizer': 'Adamax'}
# -0.541717 (0.739223) with: {'nodes': 64, 'optimizer': 'Nadam'}
# -0.016222 (0.012238) with: {'nodes': 256, 'optimizer': 'SGD'}
# -0.005923 (0.002721) with: {'nodes': 256, 'optimizer': 'RMSprop'}
# -0.025149 (0.021637) with: {'nodes': 256, 'optimizer': 'Adagrad'}
# -0.012170 (0.010059) with: {'nodes': 256, 'optimizer': 'Adadelta'}
# -0.053060 (0.072679) with: {'nodes': 256, 'optimizer': 'Adam'}
# -0.045553 (0.026816) with: {'nodes': 256, 'optimizer': 'Adamax'}
# -0.013757 (0.004166) with: {'nodes': 256, 'optimizer': 'Nadam'}
# -0.482189 (0.180166) with: {'nodes': 512, 'optimizer': 'SGD'}
# -0.007339 (0.008397) with: {'nodes': 512, 'optimizer': 'RMSprop'}
# -0.564095 (0.790036) with: {'nodes': 512, 'optimizer': 'Adagrad'}
# -0.016042 (0.014689) with: {'nodes': 512, 'optimizer': 'Adadelta'}
# -0.053261 (0.065258) with: {'nodes': 512, 'optimizer': 'Adam'}
# -0.007946 (0.002475) with: {'nodes': 512, 'optimizer': 'Adamax'}
# -0.037257 (0.024939) with: {'nodes': 512, 'optimizer': 'Nadam'}
# /usr/local/lib/python2.7/dist-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %% [markdown]
# ```
# The parameters of the best model are:
# {'nodes': 512, 'optimizer': 'Adam'}
# Best: -0.001127 using {'nodes': 512, 'optimizer': 'Adam'}
# -0.020475 (0.011958) with: {'nodes': 64, 'optimizer': 'SGD'}
# -0.185514 (0.233084) with: {'nodes': 64, 'optimizer': 'RMSprop'}
# -0.068453 (0.080421) with: {'nodes': 64, 'optimizer': 'Adagrad'}
# -0.008114 (0.006710) with: {'nodes': 64, 'optimizer': 'Adadelta'}
# -0.011764 (0.002122) with: {'nodes': 64, 'optimizer': 'Adam'}
# -0.009617 (0.006625) with: {'nodes': 64, 'optimizer': 'Adamax'}
# -0.009559 (0.007993) with: {'nodes': 64, 'optimizer': 'Nadam'}
# -1.380540 (1.757830) with: {'nodes': 256, 'optimizer': 'SGD'}
# -0.032235 (0.032159) with: {'nodes': 256, 'optimizer': 'RMSprop'}
# -0.067907 (0.049305) with: {'nodes': 256, 'optimizer': 'Adagrad'}
# -0.068727 (0.089964) with: {'nodes': 256, 'optimizer': 'Adadelta'}
# -0.027269 (0.026638) with: {'nodes': 256, 'optimizer': 'Adam'}
# -0.041329 (0.029043) with: {'nodes': 256, 'optimizer': 'Adamax'}
# -0.064827 (0.074787) with: {'nodes': 256, 'optimizer': 'Nadam'}
# -145798986.733920 (206190904.276698) with: {'nodes': 512, 'optimizer': 'SGD'}
# -0.163440 (0.169677) with: {'nodes': 512, 'optimizer': 'RMSprop'}
# -0.392960 (0.335829) with: {'nodes': 512, 'optimizer': 'Adagrad'}
# -0.013752 (0.007382) with: {'nodes': 512, 'optimizer': 'Adadelta'}
# -0.001127 (0.000205) with: {'nodes': 512, 'optimizer': 'Adam'}
# -0.024316 (0.019527) with: {'nodes': 512, 'optimizer': 'Adamax'}
# -0.145975 (0.075882) with: {'nodes': 512, 'optimizer': 'Nadam'}
#
# The parameters of the best model are:
# {'dropout': 0.1, 'batch_size': 64}
# Best: -0.006063 using {'dropout': 0.1, 'batch_size': 64}
# -0.024423 (0.023268) with: {'dropout': 0.1, 'batch_size': 32}
# -0.009315 (0.003618) with: {'dropout': 0.2, 'batch_size': 32}
# -0.048194 (0.063180) with: {'dropout': 0.25, 'batch_size': 32}
# -0.049982 (0.063840) with: {'dropout': 3, 'batch_size': 32}
# -0.006059 (0.005108) with: {'dropout': 0.1, 'batch_size': 64}
# -0.102122 (0.134410) with: {'dropout': 0.2, 'batch_size': 64}
# -0.076344 (0.103381) with: {'dropout': 0.25, 'batch_size': 64}
# -0.010933 (0.006259) with: {'dropout': 3, 'batch_size': 64}
# -0.566023 (0.798861) with: {'dropout': 0.1, 'batch_size': 128}
# -0.057677 (0.061254) with: {'dropout': 0.2, 'batch_size': 128}
# -0.117953 (0.160816) with: {'dropout': 0.25, 'batch_size': 128}
# -0.024074 (0.032511) with: {'dropout': 3, 'batch_size': 128}
# -0.261105 (0.366787) with: {'dropout': 0.1, 'batch_size': 256}
# -0.008020 (0.006774) with: {'dropout': 0.2, 'batch_size': 256}
# -0.147070 (0.192942) with: {'dropout': 0.25, 'batch_size': 256}
# -0.041268 (0.052709) with: {'dropout': 3, 'batch_size': 256}
#
# The parameters of the best model are:
# {'init': 'uniform'}
# Best: -0.010251 using {'init': 'uniform'}
# -0.010244 (0.010677) with: {'init': 'uniform'}
# -0.027241 (0.015451) with: {'init': 'lecun_uniform'}
# -0.017883 (0.001736) with: {'init': 'normal'}
# -0.280621 (0.213876) with: {'init': 'zero'}
# -0.020306 (0.007447) with: {'init': 'glorot_normal'}
# -0.022209 (0.006274) with: {'init': 'glorot_uniform'}
# -0.042632 (0.043540) with: {'init': 'he_normal'}
# -0.016507 (0.005923) with: {'init': 'he_uniform'}
#
# -> 0.00039748085476458075 512, 'adam', 0.1, 'uniform', 300, 64
# ```

# %%
from aiconf import plot_model_performance, save_history_model
model = create_model(512, 'adam', 0.1, 'uniform')
model.summary()
history = model.fit(
        X_train, y_train, epochs=50, batch_size=64, 
        validation_data=(X_test, y_test), verbose=1, shuffle=True)

#0.00019193474133498967

plot_model_performance(history, model, close, X, y, TEST_SIZE)
#save_history_model(history, model, '/tmp/mlp_adam_512_0d1_uniform_300e')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_173 (Dense)            (None, 512)               4096
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_174 (Dense)            (None, 1)                 513
# =================================================================
# Total params: 4,609
# Trainable params: 4,609
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1000 samples, validate on 250 samples
# Epoch 1/50
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1068 - val_loss: 0.0061
# Epoch 2/50
# 1000/1000 [==============================] - 0s 161us/step - loss: 0.0106 - val_loss: 0.0030
# Epoch 3/50
# 1000/1000 [==============================] - 0s 125us/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 4/50
# 1000/1000 [==============================] - 0s 102us/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 5/50
# 1000/1000 [==============================] - 0s 107us/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 6/50
# 1000/1000 [==============================] - 0s 99us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 7/50
# 1000/1000 [==============================] - 0s 102us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 8/50
# 1000/1000 [==============================] - 0s 140us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 9/50
# 1000/1000 [==============================] - 0s 110us/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 10/50
# 1000/1000 [==============================] - 0s 102us/step - loss: 0.0011 - val_loss: 9.9608e-04
# Epoch 11/50
# 1000/1000 [==============================] - 0s 100us/step - loss: 0.0010 - val_loss: 9.6764e-04
# Epoch 12/50
# 1000/1000 [==============================] - 0s 91us/step - loss: 0.0011 - val_loss: 9.5501e-04
# Epoch 13/50
# 1000/1000 [==============================] - 0s 145us/step - loss: 0.0010 - val_loss: 9.4869e-04
# Epoch 14/50
# 1000/1000 [==============================] - 0s 101us/step - loss: 0.0011 - val_loss: 9.4946e-04
# Epoch 15/50
# 1000/1000 [==============================] - 0s 92us/step - loss: 0.0011 - val_loss: 9.3627e-04
# Epoch 16/50
# 1000/1000 [==============================] - 0s 99us/step - loss: 0.0010 - val_loss: 9.4534e-04
# Epoch 17/50
# 1000/1000 [==============================] - 0s 102us/step - loss: 0.0011 - val_loss: 9.2296e-04
# Epoch 18/50
# 1000/1000 [==============================] - 0s 92us/step - loss: 9.8869e-04 - val_loss: 9.1338e-04
# Epoch 19/50
# 1000/1000 [==============================] - 0s 110us/step - loss: 0.0011 - val_loss: 9.3485e-04
# Epoch 20/50
# 1000/1000 [==============================] - 0s 101us/step - loss: 0.0011 - val_loss: 9.0306e-04
# Epoch 21/50
# 1000/1000 [==============================] - 0s 92us/step - loss: 0.0010 - val_loss: 8.9689e-04
# Epoch 22/50
# 1000/1000 [==============================] - 0s 91us/step - loss: 9.9290e-04 - val_loss: 8.8770e-04
# Epoch 23/50
# 1000/1000 [==============================] - 0s 103us/step - loss: 9.7765e-04 - val_loss: 9.1657e-04
# Epoch 24/50
# 1000/1000 [==============================] - 0s 143us/step - loss: 9.8168e-04 - val_loss: 8.7101e-04
# Epoch 25/50
# 1000/1000 [==============================] - 0s 153us/step - loss: 0.0010 - val_loss: 8.6493e-04
# Epoch 26/50
# 1000/1000 [==============================] - 0s 87us/step - loss: 9.4604e-04 - val_loss: 8.7560e-04
# Epoch 27/50
# 1000/1000 [==============================] - 0s 103us/step - loss: 0.0011 - val_loss: 8.5218e-04
# Epoch 28/50
# 1000/1000 [==============================] - 0s 103us/step - loss: 9.6671e-04 - val_loss: 9.0251e-04
# Epoch 29/50
# 1000/1000 [==============================] - 0s 104us/step - loss: 9.7048e-04 - val_loss: 9.6356e-04
# Epoch 30/50
# 1000/1000 [==============================] - 0s 120us/step - loss: 9.7213e-04 - val_loss: 8.3887e-04
# Epoch 31/50
# 1000/1000 [==============================] - 0s 115us/step - loss: 8.9168e-04 - val_loss: 8.2599e-04
# Epoch 32/50
# 1000/1000 [==============================] - 0s 115us/step - loss: 9.5517e-04 - val_loss: 8.6965e-04
# Epoch 33/50
# 1000/1000 [==============================] - 0s 105us/step - loss: 8.9917e-04 - val_loss: 8.3201e-04
# Epoch 34/50
# 1000/1000 [==============================] - 0s 99us/step - loss: 8.9419e-04 - val_loss: 8.0013e-04
# Epoch 35/50
# 1000/1000 [==============================] - 0s 104us/step - loss: 8.9225e-04 - val_loss: 7.9184e-04
# Epoch 36/50
# 1000/1000 [==============================] - 0s 102us/step - loss: 9.2446e-04 - val_loss: 8.0690e-04
# Epoch 37/50
# 1000/1000 [==============================] - 0s 98us/step - loss: 9.1191e-04 - val_loss: 7.9994e-04
# Epoch 38/50
# 1000/1000 [==============================] - 0s 94us/step - loss: 8.9930e-04 - val_loss: 7.6871e-04
# Epoch 39/50
# 1000/1000 [==============================] - 0s 114us/step - loss: 9.2463e-04 - val_loss: 7.7426e-04
# Epoch 40/50
# 1000/1000 [==============================] - 0s 95us/step - loss: 9.0689e-04 - val_loss: 8.0810e-04
# Epoch 41/50
# 1000/1000 [==============================] - 0s 96us/step - loss: 8.7374e-04 - val_loss: 7.9439e-04
# Epoch 42/50
# 1000/1000 [==============================] - 0s 115us/step - loss: 8.2029e-04 - val_loss: 7.5189e-04
# Epoch 43/50
# 1000/1000 [==============================] - 0s 107us/step - loss: 9.2340e-04 - val_loss: 7.3181e-04
# Epoch 44/50
# 1000/1000 [==============================] - 0s 95us/step - loss: 9.0657e-04 - val_loss: 7.5542e-04
# Epoch 45/50
# 1000/1000 [==============================] - 0s 100us/step - loss: 8.1949e-04 - val_loss: 7.1941e-04
# Epoch 46/50
# 1000/1000 [==============================] - 0s 139us/step - loss: 7.9379e-04 - val_loss: 7.2084e-04
# Epoch 47/50
# 1000/1000 [==============================] - 0s 91us/step - loss: 7.5661e-04 - val_loss: 7.0342e-04
# Epoch 48/50
# 1000/1000 [==============================] - 0s 100us/step - loss: 7.6737e-04 - val_loss: 6.9939e-04
# Epoch 49/50
# 1000/1000 [==============================] - 0s 94us/step - loss: 8.6148e-04 - val_loss: 7.0361e-04
# Epoch 50/50
# 1000/1000 [==============================] - 0s 92us/step - loss: 7.8946e-04 - val_loss: 7.4286e-04
# SCORE model 0.00020401724032126367

# %% [markdown]
# ## try a different model architecture

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Activation
from aiconf import plot_model_performance

model = Sequential()
model.add(LSTM(256, input_shape=(WINDOW,1)))
#model.add(Dropout(0.25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.summary()

#Reshape data for (Sample,Timestep,Features) 
X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],1))

#Fit model with history to check for overfitting
history = model.fit(X_train, y_train, epochs=30, validation_data=(X_test, y_test), shuffle=True)
score = model.evaluate(X_test, y_test)
print score

plot_model_performance(history, model, close, X, y, TEST_SIZE)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 256)               264192
# _________________________________________________________________
# dense_175 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 264,449
# Trainable params: 264,449
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1000 samples, validate on 250 samples
# Epoch 1/30
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0295 - val_loss: 0.0030
# Epoch 2/30
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 3/30
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.0826e-04 - val_loss: 0.0010
# Epoch 4/30
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.3530e-04 - val_loss: 0.0013
# Epoch 5/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 9.3137e-04 - val_loss: 0.0010
# Epoch 6/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 9.0711e-04 - val_loss: 0.0010
# Epoch 7/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.9950e-04 - val_loss: 0.0011
# Epoch 8/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 9.0369e-04 - val_loss: 0.0010
# Epoch 9/30
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.1192e-04 - val_loss: 9.9983e-04
# Epoch 10/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.5142e-04 - val_loss: 9.8474e-04
# Epoch 11/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.4646e-04 - val_loss: 9.9604e-04
# Epoch 12/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.5820e-04 - val_loss: 9.7017e-04
# Epoch 13/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.3975e-04 - val_loss: 9.6590e-04
# Epoch 14/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.3831e-04 - val_loss: 0.0011
# Epoch 15/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 9.4893e-04 - val_loss: 9.2486e-04
# Epoch 16/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.8622e-04 - val_loss: 0.0011
# Epoch 17/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.3774e-04 - val_loss: 9.0502e-04
# Epoch 18/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.9341e-04 - val_loss: 9.8981e-04
# Epoch 19/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.2329e-04 - val_loss: 0.0010
# Epoch 20/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.9201e-04 - val_loss: 8.8459e-04
# Epoch 21/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 8.4312e-04 - val_loss: 8.7096e-04
# Epoch 22/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.6329e-04 - val_loss: 9.5856e-04
# Epoch 23/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.7631e-04 - val_loss: 9.0976e-04
# Epoch 24/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.6788e-04 - val_loss: 8.8311e-04
# Epoch 25/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.9172e-04 - val_loss: 8.1937e-04
# Epoch 26/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.6368e-04 - val_loss: 8.8652e-04
# Epoch 27/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.9001e-04 - val_loss: 8.5529e-04
# Epoch 28/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.5311e-04 - val_loss: 8.4165e-04
# Epoch 29/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 7.2140e-04 - val_loss: 8.2851e-04
# Epoch 30/30
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0011 - val_loss: 0.0013
# 250/250 [==============================] - 0s 317us/step
# 0.0013382490174844862
# SCORE model 0.0004924075335729867

# %% [markdown]
# ## MLP vs LSTM

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from aiconf import fit_scaler, scale, prepare_regression_samples, plot_loaded_model_performance

WINDOW = 7
TEST_SIZE = 0.2

df = pd.read_csv('/data/historical-SP500.csv', index_col='Date', parse_dates=True).sort_index()
df = df[df.index.values > np.datetime64('2000-01-01')]
close = df['Close'][0:(1250+WINDOW+1)]
fit_scaler(close, TEST_SIZE)
sclose = scale(close).reshape(close.shape[0], 1)
X,y = prepare_regression_samples(sclose, WINDOW)

plot_loaded_model_performance('/models/regression_mlp_300e', close, X, y, TEST_SIZE, loss=True, score=True, predicted=True)
plot_loaded_model_performance('/models/regression_lstm_300e', close, X, y, TEST_SIZE, loss=True, score=True, predicted=True)
# Out:
# MODEL:  /models/regression_mlp_300e
# SCORE /models/regression_mlp_300e 0.00011454654962290078
# MODEL:  /models/regression_lstm_300e
# SCORE /models/regression_lstm_300e 0.0001845656658988446
